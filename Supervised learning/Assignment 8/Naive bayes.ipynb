# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv(r"C:\Users\Suyash Tambe\Desktop\Supervised ML\Assignment 8\Naive bayes dataset.csv")

# %%
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
print("Dataset Information:")
print(df.info())
print("\nDataset Description:")
print(df.describe())
print("\nFirst few rows of the dataset:")
print(df.head())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None
#
# Dataset Description:
# ...

# %%
data_encoded = pd.get_dummies(df)

# %%
# Inspect column names of the encoded dataset
print(data_encoded.columns)
# Out:
# Index(['39', ' 77516', ' 13', ' 2174', ' 0', ' 40', ' State-gov_ ?',
#        ' State-gov_ Federal-gov', ' State-gov_ Local-gov',
#        ' State-gov_ Never-worked',
#        ...
#        ' United-States_ Scotland', ' United-States_ South',
#        ' United-States_ Taiwan', ' United-States_ Thailand',
#        ' United-States_ Trinadad&Tobago', ' United-States_ United-States',
#        ' United-States_ Vietnam', ' United-States_ Yugoslavia',
#        ' <=50K_ <=50K', ' <=50K_ >50K'],
#       dtype='object', length=110)

# %%
X = data_encoded.drop(' <=50K_ >50K', axis=1)  # Features
y = data_encoded[' <=50K_ >50K']  # Target variable

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
naive_bayes = GaussianNB()
naive_bayes.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = naive_bayes.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7940437412750116
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.95      0.87      8116
#         True       0.67      0.31      0.42      2629
#
#     accuracy                           0.79     10745
#    macro avg       0.74      0.63      0.65     10745
# weighted avg       0.78      0.79      0.76     10745
